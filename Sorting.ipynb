# %% [markdown]
# ### Bubble Sort

# %%
def bubble_sort(arr):
    n = len(arr)
    
    for i in range(n):
        # Track if a swap was made during this pass
        swapped = False
        
        # The last i elements are already in place
        for j in range(0, n - i - 1):
            # Compare adjacent elements
            if arr[j] > arr[j + 1]:
                # Swap if they are in the wrong order
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                swapped = True
                print(i)
                print(A)
                print('\n')
        
        # If no two elements were swapped in the inner loop, the array is sorted
        if not swapped:
            break
                
A = [10, 4, 43, 5, 57, 91, 45, 9, 7]
bubble_sort(A)
# Out:
# 0
# [4, 10, 43, 5, 57, 91, 45, 9, 7]
#
#
# 0
# [4, 10, 5, 43, 57, 91, 45, 9, 7]
#
#
# 0
# [4, 10, 5, 43, 57, 45, 91, 9, 7]
#
#
# 0
# [4, 10, 5, 43, 57, 45, 9, 91, 7]
#
#
# 0
# [4, 10, 5, 43, 57, 45, 9, 7, 91]
#
#
# 1
# [4, 5, 10, 43, 57, 45, 9, 7, 91]
#
#
# 1
# [4, 5, 10, 43, 45, 57, 9, 7, 91]
#
#
# 1
# [4, 5, 10, 43, 45, 9, 57, 7, 91]
#
#
# 1
# [4, 5, 10, 43, 45, 9, 7, 57, 91]
#
#
# 2
# [4, 5, 10, 43, 9, 45, 7, 57, 91]
#
#
# 2
# [4, 5, 10, 43, 9, 7, 45, 57, 91]
#
#
# 3
# [4, 5, 10, 9, 43, 7, 45, 57, 91]
#
#
# 3
# [4, 5, 10, 9, 7, 43, 45, 57, 91]
#
#
# 4
# [4, 5, 9, 10, 7, 43, 45, 57, 91]
#
#
# 4
# [4, 5, 9, 7, 10, 43, 45, 57, 91]
#
#
# 5
# [4, 5, 7, 9, 10, 43, 45, 57, 91]

# %% [markdown]
# ### Selection Sort

# %%
def selectionSort(A):
    for i in range(len(A)-1, 0, -1):

# %%
def selection_sort(arr):
    n = len(arr)
    
    for i in range(n):
        # Find the minimum element in the remaining unsorted array
        min_index = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        
        # Swap the found minimum element with the first element
        arr[i], arr[min_index] = arr[min_index], arr[i]
        
        print(i)
        print(arr, '\n')

A = [10, 4, 43, 5, 57, 91, 45, 9, 7]
selection_sort(A)
# Out:
# 0
# [4, 10, 43, 5, 57, 91, 45, 9, 7]
#
# 1
# [4, 5, 43, 10, 57, 91, 45, 9, 7]
#
# 2
# [4, 5, 7, 10, 57, 91, 45, 9, 43]
#
# 3
# [4, 5, 7, 9, 57, 91, 45, 10, 43]
#
# 4
# [4, 5, 7, 9, 10, 91, 45, 57, 43]
#
# 5
# [4, 5, 7, 9, 10, 43, 45, 57, 91]
#
# 6
# [4, 5, 7, 9, 10, 43, 45, 57, 91]
#
# 7
# [4, 5, 7, 9, 10, 43, 45, 57, 91]
#
# 8
# [4, 5, 7, 9, 10, 43, 45, 57, 91]

# %% [markdown]
# ### Insertion Sort

# %%
def insertion_sort(arr):
    # Start from the second element (index 1) as the first element is already "sorted"
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        
        # Move elements of arr[0..i-1], that are greater than key, to one position ahead
        # of their current position
        while j >= 0 and key < arr[j]:
            arr[j + 1] = arr[j]
            j -= 1
            
            print(i, j)
            print(arr, '\n')
        
        # Place the key after the element just smaller than it
        arr[j + 1] = key
        
        print(i, j)
        print(arr, '\n')
        

A = [10, 4, 43, 5, 57, 91, 45, 9, 7]
insertion_sort(A)
# Out:
# 1 -1
# [10, 10, 43, 5, 57, 91, 45, 9, 7]
#
# 1 -1
# [4, 10, 43, 5, 57, 91, 45, 9, 7]
#
# 2 1
# [4, 10, 43, 5, 57, 91, 45, 9, 7]
#
# 3 1
# [4, 10, 43, 43, 57, 91, 45, 9, 7]
#
# 3 0
# [4, 10, 10, 43, 57, 91, 45, 9, 7]
#
# 3 0
# [4, 5, 10, 43, 57, 91, 45, 9, 7]
#
# 4 3
# [4, 5, 10, 43, 57, 91, 45, 9, 7]
#
# 5 4
# [4, 5, 10, 43, 57, 91, 45, 9, 7]
#
# 6 4
# [4, 5, 10, 43, 57, 91, 91, 9, 7]
#
# 6 3
# [4, 5, 10, 43, 57, 57, 91, 9, 7]
#
# 6 3
# [4, 5, 10, 43, 45, 57, 91, 9, 7]
#
# 7 5
# [4, 5, 10, 43, 45, 57, 91, 91, 7]
#
# 7 4
# [4, 5, 10, 43, 45, 57, 57, 91, 7]
#
# 7 3
# [4, 5, 10, 43, 45, 45, 57, 91, 7]
#
# 7 2
# [4, 5, 10, 43, 43, 45, 57, 91, 7]
#
# 7 1
# [4, 5, 10, 10, 43, 45, 57, 91, 7]
#
# 7 1
# [4, 5, 9, 10, 43, 45, 57, 91, 7]
#
# 8 6
# [4, 5, 9, 10, 43, 45, 57, 91, 91]
#
# 8 5
# [4, 5, 9, 10, 43, 45, 57, 57, 91]
#
# 8 4
# [4, 5, 9, 10, 43, 45, 45, 57, 91]
#
# 8 3
# [4, 5, 9, 10, 43, 43, 45, 57, 91]
#
# 8 2
# [4, 5, 9, 10, 10, 43, 45, 57, 91]
#
# 8 1
# [4, 5, 9, 9, 10, 43, 45, 57, 91]
#
# 8 1
# [4, 5, 7, 9, 10, 43, 45, 57, 91]

# %% [markdown]
# ### Shell Sort

# %%
def shell_sort(arr):
    n = len(arr)
    gap = n // 2  # Initialize the gap size
    
    # Start with a large gap, then reduce the gap
    while gap > 0:
        # Perform a gapped insertion sort for this gap size
        for i in range(gap, n):
            temp = arr[i]
            j = i
            
            # Shift earlier gap-sorted elements up until the correct location for arr[i] is found
            while j >= gap and arr[j - gap] > temp:
                arr[j] = arr[j - gap]
                j -= gap
            
            # Place temp (the original arr[i]) in its correct location
            arr[j] = temp
            print(i, gap)
            print(arr)
            
        gap //= 2  # Reduce the gap for the next iteration
        

A = [10, 4, 43, 5, 57, 91, 45, 9, 7]
shell_sort(A)
# Out:
# 4 4
# [10, 4, 43, 5, 57, 91, 45, 9, 7]
# 5 4
# [10, 4, 43, 5, 57, 91, 45, 9, 7]
# 6 4
# [10, 4, 43, 5, 57, 91, 45, 9, 7]
# 7 4
# [10, 4, 43, 5, 57, 91, 45, 9, 7]
# 8 4
# [7, 4, 43, 5, 10, 91, 45, 9, 57]
# 2 2
# [7, 4, 43, 5, 10, 91, 45, 9, 57]
# 3 2
# [7, 4, 43, 5, 10, 91, 45, 9, 57]
# 4 2
# [7, 4, 10, 5, 43, 91, 45, 9, 57]
# 5 2
# [7, 4, 10, 5, 43, 91, 45, 9, 57]
# 6 2
# [7, 4, 10, 5, 43, 91, 45, 9, 57]
# 7 2
# [7, 4, 10, 5, 43, 9, 45, 91, 57]
# 8 2
# [7, 4, 10, 5, 43, 9, 45, 91, 57]
# 1 1
# [4, 7, 10, 5, 43, 9, 45, 91, 57]
# 2 1
# [4, 7, 10, 5, 43, 9, 45, 91, 57]
# 3 1
# [4, 5, 7, 10, 43, 9, 45, 91, 57]
# 4 1
# [4, 5, 7, 10, 43, 9, 45, 91, 57]
# 5 1
# [4, 5, 7, 9, 10, 43, 45, 91, 57]
# 6 1
# [4, 5, 7, 9, 10, 43, 45, 91, 57]
# 7 1
# [4, 5, 7, 9, 10, 43, 45, 91, 57]
# 8 1
# [4, 5, 7, 9, 10, 43, 45, 57, 91]

# %% [markdown]
# ### Merge Sort

# %%
def merge_sort(arr):
    if len(arr) > 1:
        # Find the middle point and divide the array into two halves
        mid = len(arr) // 2
        left_half = arr[:mid]
        right_half = arr[mid:]
        
        print(left_half, right_half)
        # Recursively sort both halves
        merge_sort(left_half)
        merge_sort(right_half)
        
        # Initialize pointers for left_half, right_half, and the main array
        i = j = k = 0

        # Merge the sorted halves back into the main array
        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                arr[k] = left_half[i]
                i += 1
            else:
                arr[k] = right_half[j]
                j += 1
            k += 1

        # Copy any remaining elements of left_half, if any
        while i < len(left_half):
            arr[k] = left_half[i]
            i += 1
            k += 1

        # Copy any remaining elements of right_half, if any
        while j < len(right_half):
            arr[k] = right_half[j]
            j += 1
            k += 1
            
        print(arr)
            

A = [10, 4, 43, 5, 57, 91, 45, 9, 7]
merge_sort(A)
# Out:
# [10, 4, 43, 5] [57, 91, 45, 9, 7]
# [10, 4] [43, 5]
# [10] [4]
# [4, 10]
# [43] [5]
# [5, 43]
# [4, 5, 10, 43]
# [57, 91] [45, 9, 7]
# [57] [91]
# [57, 91]
# [45] [9, 7]
# [9] [7]
# [7, 9]
# [7, 9, 45]
# [7, 9, 45, 57, 91]
# [4, 5, 7, 9, 10, 43, 45, 57, 91]

# %% [markdown]
# ### Quick Sort

# %%
def quick_sort(arr):
    # Base case: arrays with 0 or 1 element are already sorted
    if len(arr) <= 1:
        return arr
    else:
        # Choose the pivot element (last element in this case)
        pivot = arr[-1]
        left = []
        right = []
        equal = []

        # Partition the array into three parts
        for x in arr:
            if x < pivot:
                left.append(x)
            elif x > pivot:
                right.append(x)
            else:
                equal.append(x)
        print(pivot, arr)
        print(left, equal, right)
        # Recursively sort the left and right sub-arrays
        return quick_sort(left) + equal + quick_sort(right)

# Example usage:
arr = [10, 4, 43, 5, 57, 91, 45, 9, 7]
sorted_arr = quick_sort(arr)
print("Sorted array:", sorted_arr)
# Out:
# 7 [10, 4, 43, 5, 57, 91, 45, 9, 7]
# [4, 5] [7] [10, 43, 57, 91, 45, 9]
# 5 [4, 5]
# [4] [5] []
# 9 [10, 43, 57, 91, 45, 9]
# [] [9] [10, 43, 57, 91, 45]
# 45 [10, 43, 57, 91, 45]
# [10, 43] [45] [57, 91]
# 43 [10, 43]
# [10] [43] []
# 91 [57, 91]
# [57] [91] []
# Sorted array: [4, 5, 7, 9, 10, 43, 45, 57, 91]

# %% [markdown]
# ### Counting Sort

# %%
def counting_sort(arr):
    # Find the maximum value in the array
    max_val = max(arr)
    min_val = min(arr)
    
    # Range of elements
    range_of_elements = max_val - min_val + 1
    
    # Create a count array to store the count of each unique object
    count = [0] * range_of_elements
    
    # Create output array to store the sorted elements
    output = [0] * len(arr)
    
    # Store the count of each element in count array
    for num in arr:
        count[num - min_val] += 1
    
    # Change count[i] so that count[i] contains the actual position of this element in the output array
    for i in range(1, len(count)):
        count[i] += count[i - 1]
    
    # Build the output array
    for num in reversed(arr):
        output[count[num - min_val] - 1] = num
        count[num - min_val] -= 1
    
    # Copy the sorted elements into the original array
    for i in range(len(arr)):
        arr[i] = output[i]

# Example usage:
arr = [10, 4, 43, 5, 57, 91, 45, 9, 7]
counting_sort(arr)
print("Sorted array:", arr)
# Out:
# Sorted array: [4, 5, 7, 9, 10, 43, 45, 57, 91]

# %% [markdown]
# ### Bucket Sort

# %%
def bucket_sort(arr):
    if len(arr) == 0:
        return arr

    # Determine minimum and maximum values in the array
    min_val = min(arr)
    max_val = max(arr)
    
    # Number of buckets
    bucket_count = len(arr)
    
    # Create buckets
    buckets = [[] for _ in range(bucket_count)]
    
    # Distribute elements into the appropriate bucket
    for num in arr:
        index = int(bucket_count * (num - min_val) / (max_val - min_val + 1))
        buckets[index].append(num)
    
    # Sort individual buckets and concatenate the results
    sorted_array = []
    for bucket in buckets:
        sorted_array.extend(sorted(bucket))
    
    return sorted_array

# Example usage:
arr = [0.42, 0.32, 0.23, 0.52, 0.25, 0.47, 0.51]
sorted_arr = bucket_sort(arr)
print("Sorted array:", sorted_arr)
# Out:
# Sorted array: [0.23, 0.25, 0.32, 0.42, 0.47, 0.51, 0.52]

# %% [markdown]
# ### Radix Sort

# %%
def counting_sort_for_radix(arr, exp):
    n = len(arr)
    
    # Initialize output array
    output = [0] * n
    
    # Initialize count array with 10 (for digits 0 to 9)
    count = [0] * 10
    
    # Store the count of occurrences in count[]
    for i in range(n):
        index = arr[i] // exp
        count[index % 10] += 1
    
    # Change count[i] so that count[i] contains the actual position of this digit in output[]
    for i in range(1, 10):
        count[i] += count[i - 1]
    
    # Build the output array
    for i in range(n - 1, -1, -1):
        index = arr[i] // exp
        output[count[index % 10] - 1] = arr[i]
        count[index % 10] -= 1
    
    # Copy the output array to arr[], so that arr now contains sorted numbers according to the current digit
    for i in range(n):
        arr[i] = output[i]

def radix_sort(arr):
    # Find the maximum number to determine the number of digits
    max_val = max(arr)
    
    # Do counting sort for every digit, starting from least significant digit
    exp = 1
    while max_val // exp > 0:
        counting_sort_for_radix(arr, exp)
        exp *= 10

# Example usage:
arr = [170, 45, 75, 90, 802, 24, 2, 66]
radix_sort(arr)
print("Sorted array:", arr)
# Out:
# Sorted array: [2, 24, 45, 66, 75, 90, 170, 802]
